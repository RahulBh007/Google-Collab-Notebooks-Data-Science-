# %%
#Day2 ~ Python Basics

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 45
print(a)
# Out:
# 45

# %%
type(a)
# Out:
# int

# %%
b = 3.14

# %%
c = "New York"

# %%
d = True

# %%
print(a,b,c,d)
# Out:
# 45 3.14 New York True

# %%
a = input("Enter your name:")
a
# Out:
# Enter your name:Rahul
# 'Rahul'

# %%
a = int(input("Enter 1st no:"))
b= int(input("Enter 2nd no:"))
c = a+b
c
# Out:
# Enter 1st no:10
# Enter 2nd no:10
# 20

# %%
a = int(input("Enter the number:"))
square = a**2
print(f'the square of {a} is {square}')
# Out:
# Enter the number:5
# the square of 5 is 25

# %%
a = "Welcome to Disneyland"
a[0]
# Out:
# 'Welcome to Disneyland'

# %%
a[11:17]
# Out:
# 'Disney'

# %%
a[:-1]
# Out:
# 'Welcome to Disneylan'

# %%
a[::-1]
# Out:
# 'dnalyensiD ot emocleW'

# %%
#PY Sequences (List,Tuples,Set & Dictionary)

# %%
a = [1,2,3,4,5]
type(a)
# Out:
# list

# %%
b = [25,'Hello',3.8,True]
type(b)
# Out:
# list

# %%
b.append('London')
b
# Out:
# [25, 'Hello', 3.8, True, 'London']

# %%
b.insert(2,'Car')
b
# Out:
# [25, 'Hello', 'Car', 3.8, True, 'London']

# %%
c = ['Argentina','Monaco']
b.extend(c)
b
# Out:
# ['London', 'Argentina', 'Monaco']
